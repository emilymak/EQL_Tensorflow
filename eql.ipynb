# %% [markdown]
# <a href="https://colab.research.google.com/github/emilymak/EQL_Tensorflow/blob/master/eql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
import tensorflow
print(tensorflow.__version__)
# !python --version
from sympy import *
# Out:
# 1.15.2
# Python 3.7.13
# None

# %%
# !git clone https://github.com/martius-lab/EQL_Tensorflow.git
# Out:
# Cloning into 'EQL_Tensorflow'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 90 (delta 9), reused 31 (delta 6), pack-reused 53
# Unpacking objects: 100% (90/90), done.

# %%
# !python3 EQL_Tensorflow/createjobs.py '{"train_val_file": "data/F1data_train_val", "test_file": "data/F1data_test"}'
# Out:
# Using data/F1data_train_val and data/F1data_test as paths to data files.
# Jobs succesfully generated.

# %%
# !python3 EQL_Tensorflow/model_selection.py "{'results_path': 'results/model_selection'}"
# Out:
# Traceback (most recent call last):
#   File "EQL_Tensorflow/model_selection.py", line 89, in <module>
#     use_extrapolation = passed_dict['use_extrapolation']
# KeyError: 'use_extrapolation'

# %%
! for FILE in jobs/*; do $FILE; done
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from results/model_selection/27/model.ckpt-13570
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13570 into results/model_selection/27/model.ckpt.
# INFO:tensorflow:loss = 0.0, step = 13571
# INFO:tensorflow:Saving checkpoints for 13575 into results/model_selection/27/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from results/model_selection/27/model.ckpt-13575
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ...

# %%
# !python3 EQL_Tensorflow/model_selection.py "{'results_path': 'results/model_selection', 'use_extrapolation': True}"
# Out:
# Extrapolation data used.
# All instances, ordered by score:
#     val_error  ...     score
# 0   0.155575  ...  0.023425
# 0   0.259752  ...  0.467940
# 0   0.278338  ...  0.551108
# 0   0.285786  ...  0.585708
# 0   0.300372  ...  0.649916
# 0   0.300558  ...  0.651123
# 0   0.304412  ...  0.668657
# 0   0.313492  ...  0.708780
# 0   0.314384  ...  0.713566
# 0   0.317267  ...  0.726869
# 0   0.322525  ...  0.749299
# 0   0.325010  ...  0.760524
# 0   0.327329  ...  0.770917
# 0   0.329196  ...  0.779238
# 0   0.329347  ...  0.780171
# 0   0.338311  ...  0.820234
# 0   0.339036  ...  0.823630
# 0   0.342845  ...  0.842212
# 0   0.353660  ...  0.889285
# 0   0.357353  ...  0.905851
# 0   0.357968  ...  0.908385
# 0   0.378383  ...  1.000254
# 0   0.326178  ...  1.259480
#
# [23 rows x 8 columns]
# Selected model instance:
#     val_error  ...     score
# 0   0.155575  ...  0.023425
#
# [1 rows x 8 columns]

# %%
# !python3 EQL_Tensorflow/data_utils.py "{'filename': 'eql_model_data_csv'}"
# Out:
# Updating default parameters.
# WARNING:tensorflow:From EQL_Tensorflow/data_utils.py:110: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# Traceback (most recent call last):
#   File "EQL_Tensorflow/data_utils.py", line 225, in <module>
#     pickle.dump(train_set, gzip.open(train_data_file, "wb"))
# TypeError: can't pickle _thread.RLock objects

# %%
# !python3 EQL_Tensorflow/train.py '{"train_val_file": "data/data", "test_file": "data/val"}'
# Out:
# WARNING:tensorflow:From /content/EQL_Tensorflow/EQL_Layer_tf.py:70: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From EQL_Tensorflow/train.py:103: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From EQL_Tensorflow/train.py:103: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From /content/EQL_Tensorflow/utils.py:74: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# INFO:tensorflow:Using config: {'_model_dir': 'results/1', '_tf_random_seed': None, '_save_summary_steps': 1000, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': intra_op_parallelism_threads: 1
# ...
